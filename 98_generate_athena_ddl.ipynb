# %%
# Genarate DDL for Athena

# %%
# Generate the SparkSession
from lib.spark_session import get_spark_session

spark = get_spark_session("Generate DDL")
print("SPARK_APP: Spark Session UI - "+ spark.sparkContext.uiWebUrl)
# Out:
# SPARK_APP: Spark Session UI - http://952a1c63cd79:4040

# %%
# Get all tables in Landing Schema
schema_name = "edw_ld"
df_table_names = spark.sql(f"show tables in {schema_name}")
for table in df_table_names.collect():
    table_name: str = f"{schema_name}.{table['tableName']}"
    print(f"-- DDL for {table_name}")
    df = spark.read.table(table_name)
    cols:str = ""
    for col in df.dtypes:
        cols = cols + f"\t{col[0]} {col[1]}, \r\n"
    
    print(f"CREATE EXTERNAL TABLE {table_name} (")
    print(cols[:-4])
    print(")")
    print(f"""ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
LOCATION 's3://project1027657data/data_with_pyspark/warehouse/{schema_name}.db/{table['tableName']}/_symlink_format_manifest/'
;""")
# Out:
# -- DDL for edw_ld.dim_customer_ld
# CREATE EXTERNAL TABLE edw_ld.dim_customer_ld (
# 	customer_id string,
# 	name string,
# 	address string,
# 	city string,
# 	state string,
# 	zip_code string,
# 	phone_number string,
# 	email string,
# 	date_of_birth string,
# 	plan_type string,
# 	insert_dt timestamp,
# 	rundate string
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw_ld.db/dim_customer_ld/_symlink_format_manifest/'
# ;
# -- DDL for edw_ld.dim_date_ld
# CREATE EXTERNAL TABLE edw_ld.dim_date_ld (
# 	date string,
# 	day string,
# 	month string,
# 	year string,
# 	day_of_week string,
# 	insert_dt timestamp,
# 	rundate string
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw_ld.db/dim_date_ld/_symlink_format_manifest/'
# ;
# -- DDL for edw_ld.dim_product_ld
# CREATE EXTERNAL TABLE edw_ld.dim_product_ld (
# 	product_id string,
# 	product_name string,
# 	brand string,
# 	type string,
# 	flavor string,
# 	size string,
# 	price string,
# 	quantity string,
# 	expiration_date string,
# 	image_url string,
# 	insert_dt timestamp,
# 	rundate string
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw_ld.db/dim_product_ld/_symlink_format_manifest/'
# ;
# -- DDL for edw_ld.dim_store_ld
# CREATE EXTERNAL TABLE edw_ld.dim_store_ld (
# 	store_id string,
# 	store_name string,
# 	address string,
# 	city string,
# 	state string,
# 	zip_code string,
# 	phone_number string,
# 	insert_dt timestamp,
# 	rundate string
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw_ld.db/dim_store_ld/_symlink_format_manifest/'
# ;
# -- DDL for edw_ld.fact_sales_ld
# CREATE EXTERNAL TABLE edw_ld.fact_sales_ld (
# 	value string,
# 	insert_dt timestamp,
# 	rundate string
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw_ld.db/fact_sales_ld/_symlink_format_manifest/'
# ;

# %%
# Get all tables in Staging Schema
schema_name = "edw_stg"
df_table_names = spark.sql(f"show tables in {schema_name}")
for table in df_table_names.collect():
    table_name: str = f"{schema_name}.{table['tableName']}"
    print(f"-- DDL for {table_name}")
    df = spark.read.table(table_name)
    cols:str = ""
    for col in df.dtypes:
        cols = cols + f"\t{col[0]} {col[1]}, \r\n"
    
    print(f"CREATE EXTERNAL TABLE {table_name} (")
    print(cols[:-4])
    print(")")
    print(f"""ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
LOCATION 's3://project1027657data/data_with_pyspark/warehouse/{schema_name}.db/{table['tableName']}/_symlink_format_manifest/'
;""")
# Out:
# -- DDL for edw_stg.dim_customer_stg
# CREATE EXTERNAL TABLE edw_stg.dim_customer_stg (
# 	customer_id string,
# 	name string,
# 	address string,
# 	city string,
# 	state string,
# 	zip_code string,
# 	phone_number string,
# 	email string,
# 	date_of_birth date,
# 	plan_type string,
# 	insert_dt timestamp,
# 	rundate string,
# 	first_name string,
# 	last_name string,
# 	effective_start_dt timestamp,
# 	effective_end_dt timestamp,
# 	active_flg int,
# 	update_dt timestamp
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw_stg.db/dim_customer_stg/_symlink_format_manifest/'
# ;
# -- DDL for edw_stg.dim_date_stg
# CREATE EXTERNAL TABLE edw_stg.dim_date_stg (
# 	date date,
# 	day int,
# 	month int,
# 	year int,
# 	day_of_week string,
# 	insert_dt timestamp,
# 	rundate string,
# 	update_dt timestamp
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw_stg.db/dim_date_stg/_symlink_format_manifest/'
# ;
# -- DDL for edw_stg.dim_product_stg
# CREATE EXTERNAL TABLE edw_stg.dim_product_stg (
# 	product_id string,
# 	product_name string,
# 	brand string,
# 	type string,
# 	flavor string,
# 	size string,
# 	price double,
# 	image_url string,
# 	insert_dt timestamp,
# 	rundate string,
# 	expiration_dt date,
# 	effective_start_dt timestamp,
# 	effective_end_dt timestamp,
# 	active_flg int,
# 	update_dt timestamp
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw_stg.db/dim_product_stg/_symlink_format_manifest/'
# ;
# -- DDL for edw_stg.dim_store_stg
# CREATE EXTERNAL TABLE edw_stg.dim_store_stg (
# 	store_id string,
# 	store_name string,
# 	address string,
# 	city string,
# 	state string,
# 	zip_code string,
# 	phone_number string,
# 	insert_dt timestamp,
# 	rundate string,
# 	update_dt timestamp
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw_stg.db/dim_store_stg/_symlink_format_manifest/'
# ;
# -- DDL for edw_stg.fact_sales_stg
# CREATE EXTERNAL TABLE edw_stg.fact_sales_stg (
# 	cust_id string,
# 	store_id string,
# 	order_date string,
# 	qty int,
# 	tax double,
# 	discount double,
# 	line_total double,
# 	order_id string,
# 	invoice_num string,
# 	prod_id string,
# 	product_wid string,
# 	integration_key string,
# 	rundate string,
# 	insert_dt timestamp,
# 	update_dt timestamp
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw_stg.db/fact_sales_stg/_symlink_format_manifest/'
# ;

# %%
# Get all tables in DW Schema
schema_name = "edw"
df_table_names = spark.sql(f"show tables in {schema_name}")
for table in df_table_names.collect():
    table_name: str = f"{schema_name}.{table['tableName']}"
    print(f"-- DDL for {table_name}")
    df = spark.read.table(table_name)
    cols:str = ""
    for col in df.dtypes:
        cols = cols + f"\t{col[0]} {col[1]}, \r\n"
    
    print(f"CREATE EXTERNAL TABLE {table_name} (")
    print(cols[:-4])
    print(")")
    print(f"""ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
LOCATION 's3://project1027657data/data_with_pyspark/warehouse/{schema_name}.db/{table['tableName']}/_symlink_format_manifest/'
;""")
# Out:
# -- DDL for edw.dim_customer
# CREATE EXTERNAL TABLE edw.dim_customer (
# 	row_wid string,
# 	customer_id string,
# 	first_name string,
# 	last_name string,
# 	address string,
# 	city string,
# 	state string,
# 	zip_code string,
# 	phone_number string,
# 	email string,
# 	date_of_birth date,
# 	plan_type string,
# 	effective_start_dt timestamp,
# 	effective_end_dt timestamp,
# 	active_flg int,
# 	rundate string,
# 	insert_dt timestamp,
# 	update_dt timestamp
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw.db/dim_customer/_symlink_format_manifest/'
# ;
# -- DDL for edw.dim_date
# CREATE EXTERNAL TABLE edw.dim_date (
# 	row_wid string,
# 	date date,
# 	day int,
# 	month int,
# 	year int,
# 	day_of_week string,
# 	rundate string,
# 	insert_dt timestamp,
# 	update_dt timestamp
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw.db/dim_date/_symlink_format_manifest/'
# ;
# -- DDL for edw.dim_plan_type
# CREATE EXTERNAL TABLE edw.dim_plan_type (
# 	plan_type_code string,
# 	plan_name string,
# 	rundate string,
# 	insert_dt timestamp,
# 	update_dt timestamp
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw.db/dim_plan_type/_symlink_format_manifest/'
# ;
# -- DDL for edw.dim_product
# CREATE EXTERNAL TABLE edw.dim_product (
# 	row_wid string,
# 	product_id string,
# 	product_name string,
# 	brand string,
# 	type string,
# 	flavor string,
# 	size string,
# 	price double,
# 	expiration_dt date,
# 	image_url string,
# 	effective_start_dt timestamp,
# 	effective_end_dt timestamp,
# 	active_flg int,
# 	rundate string,
# 	insert_dt timestamp,
# 	update_dt timestamp
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw.db/dim_product/_symlink_format_manifest/'
# ;
# -- DDL for edw.dim_store
# CREATE EXTERNAL TABLE edw.dim_store (
# 	row_wid string,
# 	store_id string,
# 	store_name string,
# 	address string,
# 	city string,
# 	state string,
# 	zip_code string,
# 	phone_number string,
# 	rundate string,
# 	insert_dt timestamp,
# 	update_dt timestamp
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw.db/dim_store/_symlink_format_manifest/'
# ;
# -- DDL for edw.fact_sales
# CREATE EXTERNAL TABLE edw.fact_sales (
# 	date_wid string,
# 	product_wid string,
# 	store_wid string,
# 	customer_wid string,
# 	order_id string,
# 	invoice_num string,
# 	qty int,
# 	tax double,
# 	discount double,
# 	line_total double,
# 	integration_key string,
# 	rundate string,
# 	insert_dt timestamp,
# 	update_dt timestamp
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw.db/fact_sales/_symlink_format_manifest/'
# ;
# -- DDL for edw.job_control
# CREATE EXTERNAL TABLE edw.job_control (
# 	schema_name string,
# 	table_name string,
# 	max_timestamp timestamp,
# 	rundate string,
# 	insert_dt timestamp
# )
# ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
# STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
# OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
# LOCATION 's3://project1027657data/data_with_pyspark/warehouse/edw.db/job_control/_symlink_format_manifest/'
# ;

# %%
spark.stop()
